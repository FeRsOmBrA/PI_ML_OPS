# %% [markdown]
# # Proceso ETL para `steam_games`
#
#
#
# Este notebook documenta el proceso de Extracción, Transformación y Carga (ETL) aplicado al dataset `steam_games`, fundamental para la preparación de los datos en proyectos de ciencia de datos. El dataset contiene información valiosa sobre juegos disponibles en Steam, incluyendo detalles como el género, nombre, desarrollador, precio, y año de lanzamiento.

# %% [markdown]
# Librerías requeridas

# %%
import pandas as pd
import re
from utils.utils import cargar_json_gz

# %% [markdown]
# ## Extracción y Exploración de Datos
#
# Cargamos el dataset y realizamos una exploración inicial para entender su estructura.

# %%
# Ruta al archivo steam_games.json.gz
ruta_archivo_steam_games = '../data/steam_games.json.gz'

# Cargamos los datos al DataFrame steam_games
steam = cargar_json_gz(ruta_archivo_steam_games, way=0)

# %% [markdown]
# Visualizamos el DataFrame para obtener una primera idea de la estructura de los datos.

# %%
steam.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 120445 entries, 0 to 120444
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   publisher     24083 non-null  object
#  1   genres        28852 non-null  object
#  2   app_name      32133 non-null  object
#  3   title         30085 non-null  object
#  4   url           32135 non-null  object
#  5   release_date  30068 non-null  object
#  6   tags          31972 non-null  object
#  7   reviews_url   32133 non-null  object
#  8   specs         31465 non-null  object
#  9   price         30758 non-null  object
#  10  early_access  32135 non-null  object
#  11  id            32133 non-null  object
#  12  developer     28836 non-null  object
# dtypes: object(13)
# memory usage: 11.9+ MB

# %% [markdown]
# ## Búsqueda de Nulos
#
# Identificamos y tratamos valores nulos

# %%
steam.isnull().sum()
# Out:
# publisher       96362
# genres          91593
# app_name        88312
# title           90360
# url             88310
# release_date    90377
# tags            88473
# reviews_url     88312
# specs           88980
# price           89687
# early_access    88310
# id              88312
# developer       91609
# dtype: int64

# %% [markdown]
# Eliminamos las columnas 'title', 'early_access', 'url', 'reviews_url', 'tags', 'publisher', 'specs' ya que no se tendra en cuenta en procesamientos posteriores.

# %%
steam.drop(['title', 'early_access', 'url', 'reviews_url',
           'tags', 'publisher', 'specs'], axis=1, inplace=True)

# %% [markdown]
# Eliminamos las filas con valores nulos para cada variable

# %%
steam.dropna(subset=['genres', 'app_name', 'release_date',
             'price', 'id', 'developer'], inplace=True)
steam.reset_index(drop=True, inplace=True)

# %% [markdown]
# Revisamos los cambios

# %%
print(steam.isnull().sum())
steam
# Out:
# genres          0
# app_name        0
# release_date    0
# price           0
# id              0
# developer       0
# dtype: int64
#                                                   genres  \
# 0          [Action, Casual, Indie, Simulation, Strategy]
# 1                   [Free to Play, Indie, RPG, Strategy]
# 2      [Casual, Free to Play, Indie, Simulation, Sports]
# 3                            [Action, Adventure, Casual]
# 4                        [Action, Adventure, Simulation]
# ...                                                  ...
# 27457                 [Action, Adventure, Casual, Indie]
# 27458              [Casual, Indie, Simulation, Strategy]
# 27459                          [Casual, Indie, Strategy]
# 27460                        [Indie, Racing, Simulation]
# 27461                                    [Casual, Indie]
#
#                        app_name release_date         price      id  \
# 0           Lost Summoner Kitty   2018-01-04          4.99  761140
# 1                     Ironbound   2018-01-04  Free To Play  643980
# 2       Real Pool 3D - Poolians   2017-07-24  Free to Play  670290
# 3                       弹炸人2222   2017-12-07          0.99  767400
# 4         Battle Royale Trainer   2018-01-04          3.99  772540
# ...                         ...          ...           ...     ...
# 27457              Kebab it Up!   2018-01-04          1.99  745400
# 27458            Colony On Mars   2018-01-04          1.99  773640
# 27459  LOGistICAL: South Africa   2018-01-04          4.99  733530
# 27460             Russian Roads   2018-01-04          1.99  610660
# 27461       EXIT 2 - Directions   2017-09-02          4.99  658870
#
#                       developer
# 0                     Kotoshiro
# 1              Secret Level SRL
# 2                  Poolians.com
# 3                          彼岸领域
# 4           Trickjump Games Ltd
# ...                         ...
# 27457           Bidoniera Games
# 27458        Nikita "Ghost_RUS"
# 27459                    Sacada
# 27460  Laush Dmitriy Sergeevich
# 27461             xropi,stev3ns
#
# [27462 rows x 6 columns]

# %% [markdown]
# ### Transformación de Datos
#
# Aplicamos transformaciones específicas a varias columnas para normalizar y preparar los datos para el análisis.
#
# #### Normalización de Nombres
#
# Normalizamos los nombres en la columna `app_name`, eliminando caracteres especiales y uniformizando el formato de texto.

# %%
def limpiar_nombre_aplicacion(nombre):
    """
    Limpia y normaliza los nombres de las aplicaciones.

    Parámetros:
    - nombre (str): El nombre de la aplicación a limpiar.

    Retorna:
    - str: El nombre de la aplicación limpio y normalizado.
    """
    # Eliminamos caracteres especiales excepto espacios y puntos, los cuales son comunes en nombres propios o acrónimos.
    nombre_limpio = re.sub(r'[^\w\s\.]', '', nombre)

    # Normalizamos el espacio: convertimos secuencias de espacios en un único espacio
    nombre_normalizado = re.sub(r'\s+', ' ', nombre_limpio)

    # Aplicamos capitalización por palabras para preservar la importancia de nombres propios y acrónimos.
    return nombre_normalizado.title()


# Aplicamos la función de limpieza a la columna 'app_name'
steam['app_name'] = steam['app_name'].apply(limpiar_nombre_aplicacion)

# %% [markdown]
# #### Transformación de Fechas
#
# Extraemos el año de la columna `release_date` y creamos una nueva columna `release_year`.

# %%
# buscar los valores que no coinciden con el patrón de fecha yyyy-mm-dd
steam[~steam['release_date'].str.match(r'\d{4}-\d{2}-\d{2}')]
# Out:
#                                                   genres  \
# 219                                   [Adventure, Indie]
# 459                                      [RPG, Strategy]
# 462                                      [RPG, Strategy]
# 463                                      [RPG, Strategy]
# 546                                             [Racing]
# 2404   [Action, Indie, Racing, Simulation, Sports, Ea...
# 3211                                 [Action, Adventure]
# 5375   [Action, Adventure, Casual, Indie, Strategy, E...
# 5918                                         [Utilities]
# 9066                               [Indie, Early Access]
# 11139                         [Adventure, Casual, Indie]
# 13286                                      [Action, RPG]
# 14111                                    [Casual, Indie]
# 15384      [Action, Casual, Indie, Sports, Early Access]
# 16406  [Action, Casual, Free to Play, Massively Multi...
# 17374                                [Action, Adventure]
# 17429                                    [Action, Indie]
# 17760                [Adventure, Indie, RPG, Simulation]
# 18746                         [Action, Adventure, Indie]
# 19237                                           [Action]
# 21634                         [Action, Adventure, Indie]
# 22277                             [Action, Free to Play]
# 22425                                 [Adventure, Indie]
# 22995    [Audio Production, Utilities, Video Production]
# 23338                                     [Free to Play]
# 23740                                           [Action]
# 24058                                         [Strategy]
# 24344  [Adventure, Casual, Free to Play, Massively Mu...
# 24561                 [Action, Adventure, Casual, Indie]
# 25778                                           [Action]
# 25926                                              [RPG]
# 26840                                           [Action]
# 26882                                       [Simulation]
# 26923                             [Strategy, Simulation]
# 26976                                           [Casual]
# 27024                                           [Action]
# 27073                                   [Sports, Action]
# 27339                                           [Action]
# 27369                                    [Action, Indie]
#
#                                                 app_name release_date  \
# 219                                     Blueberry Garden     Jun 2009
# 459                 Age Of Wonders Ii The Wizards Throne     Oct 2010
# 462                          Age Of Wonders Shadow Magic     Oct 2010
# 463                                       Age Of Wonders     Oct 2010
# 546                               Test Drive Unlimited 2     Feb 2011
# 2404                              Altitude0 Lower Faster     Sep 2014
# 3211                       Far Cry 4 Valley Of The Yetis     Apr 2015
# 5375                                       Magma Chamber     Apr 2016
# 5918                           3Dmark Time Spy Benchmark     Jul 2016
# 9066                                                Juke     Jul 2017
# 11139                               Franky The Bumwalker         SOON
# 13286  Ys Viii Lacrimosa Of Dana イースViiilacrimosa Of ...         2018
# 14111                                Space Hit Guise Dlc     Jul 2017
# 15384                               Tuebor I Will Defend     Apr 2017
# 16406                                     Heroes Evolved     Jan 2017
# 17374  Call Of Duty Infinite Warfare Digital Deluxe E...     Nov 2016
# 17429                              Assassination Box Ost     Nov 2016
# 17760                                         Majorminor     Oct 2016
# 18746                          Necropolis Brutal Edition     Jul 2016
# 19237                         Dark Souls Iii Season Pass     Jun 2016
# 21634   Urizen Shadows Of The Cold Deluxe Frosty Edition     Aug 2015
# 22277                                         Dirty Bomb     Jun 2015
# 22425                                      Technobabylon     May 2015
# 22995                                Facerig Pro Upgrade     Feb 2015
# 23338                             Magic Barrage Bitferno     Jan 2015
# 23740          Call Of Duty Advanced Warfare Season Pass     Nov 2014
# 24058  Nobunagas Ambition Souzou Traditional Chinese ...     Aug 2014
# 24344                                       Aura Kingdom     Jul 2014
# 24561                                      Muffin Knight     May 2014
# 25778              Call Of Duty Black Ops Ii Season Pass     Feb 2013
# 25926     Sea Dogs To Each His Own Pirate Open World Rpg     Dec 2012
# 26840                Aliens Vs Predator Bughunt Map Pack     Jul 2010
# 26882             Silent Hunter 5 Battle Of The Atlantic     Mar 2010
# 26923                  Grand Ages Rome Reign Of Augustus     Jan 2010
# 26976                                          Itzabitza     Oct 2009
# 27024                                    Darkest Of Days     Sep 2009
# 27073                                          Smashball     Jun 2009
# 27339             Sniper Ghost Warrior 3 Multiplayer Map  coming soon
# 27369                                               Dusk        SOON™
#
#               price       id  \
# 219            4.99    29160
# 459            9.99    61510
# 462            9.99    61520
# 463            5.99    61500
# 546           19.99     9930
# 2404          18.99   308080
# 3211          14.99   324344
# 5375           4.99   463240
# 5918           Free   496100
# 9066           4.99   665780
# 11139          0.99   761310
# 13286         59.99   579180
# 14111          Free   676890
# 15384         24.99   521330
# 16406  Free To Play   534820
# 17374         99.99   517831
# 17429          Free   552680
# 17760         19.99   417990
# 18746         29.99   384490
# 19237         24.99   442010
# 21634          0.99   397700
# 22277  Free to Play   333930
# 22425         14.99   307580
# 22995         64.99   315200
# 23338  Free to Play   335150
# 23740         49.99   317660
# 24058         24.99   292990
# 24344  Free to Play   268420
# 24561          6.99   263700
# 25778         49.99  2028062
# 25926         14.99   223330
# 26840          7.49    10697
# 26882          9.99    48110
# 26923          6.99    23455
# 26976          9.99    40200
# 27024         19.99    37700
# 27073          Free    17730
# 27339         19.99   575301
# 27369          20.0   519860
#
#                                                developer
# 219                                         Erik Svedäng
# 459                                      Triumph Studios
# 462                                      Triumph Studios
# 463                                      Triumph Studios
# 546                                         Eden Studios
# 2404                                              Gugila
# 3211   Ubisoft Montreal, Red Storm, Shanghai, Toronto...
# 5375                                     IndieKeep Games
# 5918                                          Futuremark
# 9066                                        Jello Godfri
# 11139                               Onlyjoy`s production
# 13286                                       Nihon Falcom
# 14111                                      Artur Rezende
# 15384                   Strength in Numbers Studios, Inc
# 16406                                         Net Dragon
# 17374                                      Infinity Ward
# 17429                                     VitaliZelenyuk
# 17760                                  Tall Tail Studios
# 18746                                Harebrained Schemes
# 19237                                 FromSoftware, Inc.
# 21634                                  Bloodshadow Games
# 22277                                      Splash Damage
# 22425                                   Technocrat Games
# 22995                                   Holotech Studios
# 23338                                           Gameguyz
# 23740                  Sledgehammer Games,Raven Software
# 24058                         KOEI TECMO GAMES CO., LTD.
# 24344                                           X-Legend
# 24561                                    Angry Mob Games
# 25778                                           Treyarch
# 25926                                   BlackMark Studio
# 26840                                          Rebellion
# 26882                                    Ubisoft Romania
# 26923                                    Haemimont Games
# 26976                                         Sabi Games
# 27024                                       8monkey Labs
# 27073                                 Smashball Labs LLC
# 27339                                           CI Games
# 27369                                    David Szymanski

# %%
# encontramos el formato Jun 2009	, 2009-06-01 y unos valores que tienen SOON por lo que se eliminan
con1 = steam['release_date'].str.match(r'\d{4}-\d{2}-\d{2}')
con2 = steam['release_date'].str.match(r'[A-Z][a-z]{2} \d{4}')
con3 = ~con1 & ~con2

steam = steam[con1 & ~con2]
steam.reset_index(drop=True, inplace=True)
steam.isna().sum()
# Out:
# genres          0
# app_name        0
# release_date    0
# price           0
# id              0
# developer       0
# dtype: int64

# %%
steam['release_date'] = pd.to_datetime(steam['release_date'])
# Out:
# C:\Users\fcastano5\AppData\Local\Temp\ipykernel_23908\1839756588.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   steam['release_date'] = pd.to_datetime(steam['release_date'])

# %%
steam['release_year'] = steam['release_date'].dt.year
# Out:
# C:\Users\fcastano5\AppData\Local\Temp\ipykernel_23908\3739350701.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   steam['release_year'] = steam['release_date'].dt.year

# %%
steam
# Out:
#                                                   genres  \
# 0          [Action, Casual, Indie, Simulation, Strategy]
# 1                   [Free to Play, Indie, RPG, Strategy]
# 2      [Casual, Free to Play, Indie, Simulation, Sports]
# 3                            [Action, Adventure, Casual]
# 4                        [Action, Adventure, Simulation]
# ...                                                  ...
# 27418                 [Action, Adventure, Casual, Indie]
# 27419              [Casual, Indie, Simulation, Strategy]
# 27420                          [Casual, Indie, Strategy]
# 27421                        [Indie, Racing, Simulation]
# 27422                                    [Casual, Indie]
#
#                       app_name release_date         price      id  \
# 0          Lost Summoner Kitty   2018-01-04          4.99  761140
# 1                    Ironbound   2018-01-04  Free To Play  643980
# 2        Real Pool 3D Poolians   2017-07-24  Free to Play  670290
# 3                      弹炸人2222   2017-12-07          0.99  767400
# 4        Battle Royale Trainer   2018-01-04          3.99  772540
# ...                        ...          ...           ...     ...
# 27418              Kebab It Up   2018-01-04          1.99  745400
# 27419           Colony On Mars   2018-01-04          1.99  773640
# 27420  Logistical South Africa   2018-01-04          4.99  733530
# 27421            Russian Roads   2018-01-04          1.99  610660
# 27422        Exit 2 Directions   2017-09-02          4.99  658870
#
#                       developer  release_year
# 0                     Kotoshiro          2018
# 1              Secret Level SRL          2018
# 2                  Poolians.com          2017
# 3                          彼岸领域          2017
# 4           Trickjump Games Ltd          2018
# ...                         ...           ...
# 27418           Bidoniera Games          2018
# 27419        Nikita "Ghost_RUS"          2018
# 27420                    Sacada          2018
# 27421  Laush Dmitriy Sergeevich          2018
# 27422             xropi,stev3ns          2017
#
# [27423 rows x 7 columns]

# %% [markdown]
# #### Ajuste de Precios
#
# Transformamos la columna `price`, reemplazando "Free To Play" por 0.0 y convirtiendo a tipo float.

# %%
steam['price'] = steam['price'].apply(
    lambda x: 0.0 if isinstance(x, str) else x).astype('float')
# Out:
# C:\Users\fcastano5\AppData\Local\Temp\ipykernel_23908\1754250626.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   steam['price'] = steam['price'].apply(

# %% [markdown]
# #### Explode de Géneros
#
# Manejamos la columna `genres` que contiene listas de géneros, para poder trabajar con ellas de manera más eficiente.

# %%
steam = steam.explode("genres").dropna(
    subset=["genres"]).reset_index(drop=True)

# %% [markdown]
# ## Manejo de duplicados
#
# Con las transformaciones realizadas, en especial, el explode de la columna generos, facilita el tratamiento de los valores duplicados.

# %%
# Conteo de duplicados

steam.duplicated().sum()
# Out:
# 1

# %%
# revisamos los duplicados
steam[steam.duplicated()]
# Out:
#        genres                         app_name release_date  price      id  \
# 30981  Action  Wolfenstein Ii The New Colossus   2017-10-26  59.99  612880
#
#            developer  release_year
# 30981  Machine Games          2017

# %%
# Eliminamos los duplicados

steam.drop_duplicates(inplace=True)

# %% [markdown]
# ### Almacenamiento de Datos con Pickle
#
# Una vez que hemos limpiado y transformado el DataFrame `steam`, procedemos a almacenarlo utilizando el formato Pickle para preservar la integridad de los datos y asegurar un acceso rápido y eficiente para análisis futuros.

# %%
ruta_guardar_pickle = "../data/steam_games.pkl"

steam.to_pickle(ruta_guardar_pickle)

# %%
# Out:
#            genres             app_name release_date  price      id  \
# 0          Action  Lost Summoner Kitty   2018-01-04   4.99  761140
# 1          Casual  Lost Summoner Kitty   2018-01-04   4.99  761140
# 2           Indie  Lost Summoner Kitty   2018-01-04   4.99  761140
# 3      Simulation  Lost Summoner Kitty   2018-01-04   4.99  761140
# 4        Strategy  Lost Summoner Kitty   2018-01-04   4.99  761140
# ...           ...                  ...          ...    ...     ...
# 67927       Indie        Russian Roads   2018-01-04   1.99  610660
# 67928      Racing        Russian Roads   2018-01-04   1.99  610660
# 67929  Simulation        Russian Roads   2018-01-04   1.99  610660
# 67930      Casual    Exit 2 Directions   2017-09-02   4.99  658870
# 67931       Indie    Exit 2 Directions   2017-09-02   4.99  658870
#
#                       developer  release_year
# 0                     Kotoshiro          2018
# 1                     Kotoshiro          2018
# 2                     Kotoshiro          2018
# 3                     Kotoshiro          2018
# 4                     Kotoshiro          2018
# ...                         ...           ...
# 67927  Laush Dmitriy Sergeevich          2018
# 67928  Laush Dmitriy Sergeevich          2018
# 67929  Laush Dmitriy Sergeevich          2018
# 67930             xropi,stev3ns          2017
# 67931             xropi,stev3ns          2017
#
# [67931 rows x 7 columns]

# %%
steam.isna().sum()
# Out:
# genres          0
# app_name        0
# release_date    0
# price           0
# id              0
# developer       0
# release_year    0
# dtype: int64

# %%
# Verificar que el archivo se haya guardado correctamente

steam_recuperado = pd.read_pickle(ruta_guardar_pickle)
steam_recuperado
# Out:
#            genres             app_name release_date  price      id  \
# 0          Action  Lost Summoner Kitty   2018-01-04   4.99  761140
# 1          Casual  Lost Summoner Kitty   2018-01-04   4.99  761140
# 2           Indie  Lost Summoner Kitty   2018-01-04   4.99  761140
# 3      Simulation  Lost Summoner Kitty   2018-01-04   4.99  761140
# 4        Strategy  Lost Summoner Kitty   2018-01-04   4.99  761140
# ...           ...                  ...          ...    ...     ...
# 67927       Indie        Russian Roads   2018-01-04   1.99  610660
# 67928      Racing        Russian Roads   2018-01-04   1.99  610660
# 67929  Simulation        Russian Roads   2018-01-04   1.99  610660
# 67930      Casual    Exit 2 Directions   2017-09-02   4.99  658870
# 67931       Indie    Exit 2 Directions   2017-09-02   4.99  658870
#
#                       developer  release_year
# 0                     Kotoshiro          2018
# 1                     Kotoshiro          2018
# 2                     Kotoshiro          2018
# 3                     Kotoshiro          2018
# 4                     Kotoshiro          2018
# ...                         ...           ...
# 67927  Laush Dmitriy Sergeevich          2018
# 67928  Laush Dmitriy Sergeevich          2018
# 67929  Laush Dmitriy Sergeevich          2018
# 67930             xropi,stev3ns          2017
# 67931             xropi,stev3ns          2017
#
# [67931 rows x 7 columns]

# %% [markdown]
# # Reporte final del procesamiento
#
# 1. **`app_name`**:
#    - **Normalización de Nombres**: Se limpiaron los nombres de las aplicaciones eliminando caracteres especiales y uniformizando el formato de texto. Se permitieron puntos, considerando acrónimos o nombres propios, y se aplicó capitalización por palabras para mantener la importancia de nombres propios y acrónimos.
#
# 2. **`release_date`**:
#    - **Extracción de Año**: Se extrajo el año de la fecha de lanzamiento y se almacenó en una nueva columna `release_year`. Los valores faltantes o incorrectos fueron manejados adecuadamente, excluyendo aquellos registros sin año de lanzamiento válido.
#
#
# 3. **`price`**:
#    - **Ajuste de Valores**: Los textos indicativos de juegos gratuitos (como "Free") fueron reemplazados por 0.0, y la columna fue convertida a tipo float para representar correctamente los precios de los juegos.
#   .
#
# 4. **`genres`**:
#    - **Explosión y Limpieza**: La columna, originalmente conteniendo listas de géneros, fue "explotada" para crear filas individuales por cada género, permitiendo una mejor categorización y análisis por género.
#
#
# 5. **`id`**:
#    - **Renombrado y Limpieza**: La columna `id` fue renombrada a `item_id` para clarificar su propósito como identificador único de contenido. Se aseguró que todos los identificadores fueran únicos y se eliminaron duplicados.
#
#
# 6. **Columnas Eliminadas**:
#    - Se eliminaron varias columnas (`title`, `early_access`, `url`, `reviews_url`, `tags`, `publisher`, `specs`) que no eran necesarias para los objetivos del análisis, optimizando así el tratamiento de los datos y el rendimiento de las operaciones subsiguientes.
#
#
# 7. **Almacenamiento**:
#    - Se guardo el dataframe final usando el formato pickle
